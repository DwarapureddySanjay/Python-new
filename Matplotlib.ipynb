# %% [markdown]
# <a href="https://colab.research.google.com/github/DwarapureddySanjay/Python-new/blob/module4/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pyplot
import matplotlib.pyplot as p
import numpy as np

xpoints = np.array([0, 50])
ypoints = np.array([0, 25])

p.plot(xpoints, ypoints)
p.show()

# %%
# plotting-1
import matplotlib.pyplot as p
import numpy as np

xpoints = np.array([0, 100])
ypoints = np.array([0, 250])

p.plot(xpoints, ypoints)
p.show()

# %%
# plotting-2
import matplotlib.pyplot as p
import numpy as np

xpoints = np.array([10, 80])
ypoints = np.array([5, 100])

p.plot(xpoints, ypoints, 'o')
p.show()

# %%
# plotting-3
import matplotlib.pyplot as p
import numpy as np

xpoints = np.array([3, 5, 6, 8])
ypoints = np.array([2, 7, 1, 9])

p.plot(xpoints, ypoints)
p.show()

# %%
# plotting-4
import matplotlib.pyplot as p
import numpy as np

ypoints = np.array([2, 7, 1, 9])

p.plot(ypoints)
p.show()

# %%
# markers-1
import matplotlib.pyplot as rs
import numpy as np

ypoints = np.array([3, 67, 10, 56])

rs.plot(ypoints, marker = 'o')
rs.show()

# %%
# markers-2
import matplotlib.pyplot as r
import numpy as np

ypoints = np.array([3, 67, 10, 56])

r.plot(ypoints, marker = 'o', ms = 25, mec = 'r')
r.show()

# %%
# markers-3
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([6 ,67, 10, 56])

plt.plot(ypoints, marker = 'o', ms = 30, mfc = 'r')
plt.show()

# %%
# markers-4
import matplotlib.pyplot as p
import numpy as np

ypoints = np.array([3, 46, 15, 67])

p.plot(ypoints, marker = 'o', ms = 10, mec = 'r', mfc = 'r')
p.show()

# %%
# markers-5
import matplotlib.pyplot as p
import numpy as np

ypoints = np.array([3, 46, 15, 67])

p.plot(ypoints, marker = 'o', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')
p.show()

# %%
# markers-6
import matplotlib.pyplot as p
import numpy as np

ypoints = np.array([3, 56, 15, 67])

p.plot(ypoints, marker = 'o', ms = 30, mec = 'hotpink', mfc = 'hotpink')
p.show()

# %%
# line-1
import matplotlib.pyplot as p
import numpy as np

ypoints = np.array([2, 10, 3, 9])

p.plot(ypoints, linestyle = 'dotted')
p.show()

# %%
# line-2
import matplotlib.pyplot as p
import numpy as np

ypoints = np.array([2, 10, 3, 9])

p.plot(ypoints, linestyle = 'dashed')
p.show()

# %%
# line-3
import matplotlib.pyplot as p
import numpy as np

ypoints = np.array([2, 10, 3, 9])

p.plot(ypoints, ls = ':')
p.show()

# %%
# line-4
import matplotlib.pyplot as r
import numpy as np

ypoints = np.array([2, 10, 3, 9])

r.plot(ypoints, color = 'r')
r.show()

# %%
# line-5
import matplotlib.pyplot as r
import numpy as np

ypoints = np.array([2, 10, 3, 9])

r.plot(ypoints, c = '#4CAF50')
r.show()

# %%
# line-6
import matplotlib.pyplot as p
import numpy as np

ypoints = np.array([2, 10, 3, 9])

p.plot(ypoints, linewidth = '18.5')
p.show()

# %%
# labels-1
import matplotlib.pyplot as s
import numpy as np

x = np.array(['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC'])
y = np.array([89,80,69,89,69,79,98,79,89])

s.plot(x, y)

s.xlabel("subject name")
s.ylabel("marks")

plt.show()

# %%
# labels-2
import matplotlib.pyplot as l
import numpy as np


x = np.array(['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC'])
y = np.array([89,80,69,89,69,79,98,79,89])

l.plot(x, y)

l.title("one student data")
l.ylabel("marks scored")

l.show()

# %%
# labels-3
import numpy as np
import matplotlib.pyplot as t

x = np.array(['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC'])
y = np.array([89,80,69,89,69,79,98,79,89])

font1 = {'name':'surya','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

t.title("student data", fontdict = font1)
t.xlabel("subject name", fontdict = font2)
t.ylabel("marks", fontdict = font2)

t.plot(x, y)
t.show()

# %%
# labels-4
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC'])
y = np.array([89,80,69,89,69,79,98,79,89])

plt.title("student data", loc = 'left')
plt.xlabel("subject name")
plt.ylabel("marks")

plt.plot(x, y)
plt.show()

# %%
# grid-1
import matplotlib.pyplot as d
import numpy as np
x=np.array(['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC'])
y=np.array([89,80,69,89,69,79,98,79,89])
d.title('sem1 marks')
d.xlabel('subjects')
d.ylabel('Sanjay marks')
d.plot(x,y)
d.grid()
d.show()

# %%
# grid-2
import matplotlib.pyplot as d
import numpy as np
x=np.array(['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC'])
y=np.array([89,80,69,89,69,79,98,79,89])
d.title('sem1 marks')
d.xlabel('subjects')
d.ylabel('Sanjay marks')
d.plot(x,y)
d.grid(axis = 'x')
d.show()

# %%
# grid-3
import matplotlib.pyplot as d
import numpy as np
x=np.array(['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC'])
y=np.array([89,80,69,89,69,79,98,79,89])
d.title('sem1 marks')
d.xlabel('subjects')
d.ylabel('Sanjay marks')
d.plot(x,y)
d.grid(axis = 'y')
d.show()

# %%
# grid-4
import matplotlib.pyplot as d
import numpy as np
x=np.array(['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC'])
y=np.array([89,80,69,89,69,79,98,79,89])
d.title('sem1 marks')
d.xlabel('subjects')
d.ylabel('Sanjay marks')
d.plot(x,y)
d.grid(color = 'red', linestyle = '--', linewidth = 0.5)
d.show()

# %%
# subplot-1
import matplotlib.pyplot as d
import numpy as np
x=np.array(['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC'])
y=np.array([89,80,69,89,69,79,98,79,89])

d.subplot(1,2,1)
d.plot(x,y)
x=np.array(['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC'])
y=np.array([10, 20, 30, 40, 50, 60, 70, 80, 90])

d.subplot(1,2,2)
d.plot(x,y)
d.show()

# %%
# subplot-2
import matplotlib.pyplot as d
import numpy as np
x=np.array(['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC'])
y=np.array([89,80,69,89,69,79,98,79,89])

d.subplot(2,1,1)
d.plot(x,y)
x=np.array(['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC'])
y=np.array([10, 20, 30, 40, 50, 60, 70, 80, 90])

d.subplot(2,1,2)
d.plot(x,y)
d.show()

# %%
# subplot-3
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
# subplot-4
import matplotlib.pyplot as d
import numpy as np
x=np.array(['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC'])
y=np.array([89,80,69,89,69,79,98,79,89])
d.subplot(1,2,1)
d.plot(x,y)
d.title("subject")

x=np.array(['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC'])
y=np.array([10, 20, 30, 40, 50, 60, 70, 80, 90])

d.subplot(1,2,2)
d.plot(x,y)
d.title("marks")
d.show()

# %%
# subplot-5
import matplotlib.pyplot as d
import numpy as np
x=np.array(['CLAD','IT','C','Eng','Math-1','Math-2','EVPR','Phy','VDC'])
y=np.array([89,80,69,89,69,79,98,79,89])
d.subplot(1,2,1)
d.plot(x,y)
d.title("subject")

x=np.array(['CLAD','IT','C','Eng','Math-1','Math-2','EVPR','Phy','VDC'])
y=np.array([10, 20, 30, 40, 50, 60, 70, 80, 90])

d.subplot(1,2,2)
d.plot(x,y)
d.title("marks")
d.suptitle("student marks data")
d.show()

# %%
# scatter-1
import matplotlib.pyplot as d
import numpy as np
x=np.array(['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC'])
y=np.array([89,80,69,89,69,79,98,79,89])
d.scatter(x,y)
d.show()

# %%
# scatter-2
import matplotlib.pyplot as n
import numpy as np

#class-1 marks
x = np.array([4,7,9,7,1,19,3,8,2,13,15,7,5])
y = np.array([111,96,77,67,111,88,102,86,95,79,77,83,88])
n.scatter(x, y)

# class-2 marks
x = np.array([2,3,9,1,15,9,13,10,8,4,10,3,5,16,11])
y = np.array([101,106,84,104,89,100,88,96,95,100,79,112,91,80,85])
n.scatter(x, y)

n.show()

# %%
# scatter-3
import matplotlib.pyplot as n
import numpy as np

#class-1 marks
x = np.array([4,7,9,7,1,19,3,8,2,13,15,7,5])
y = np.array([111,96,77,67,111,88,102,86,95,79,77,83,88])
n.scatter(x, y, color = 'hotpink')

# class-2 marks
x = np.array([2,3,9,1,15,9,13,10,8,4,10,3,5,16,11])
y = np.array([101,106,84,104,89,100,88,96,95,100,79,112,91,80,85])
n.scatter(x, y, color = 'black')

n.show()

# %%
# scatter-4
import matplotlib.pyplot as plt
import numpy as np

x = np.array([4,7,9,7,1,19,3,8,2,13,15,7,5])
y = np.array([111,96,77,67,111,88,102,86,95,79,77,83,88])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
# scatter-5
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,9,7,2,17,2,9,4,11,12,9,6])
y = np.array([9,86,8,88,11,86,10,87,94,8,77,5,6])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
# scatter-6
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %%
# scatter-7
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

plt.show()

# %%
# scatter-8
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.5)

plt.show()

# %%
# scatter-9
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %%
# bargraph-1
import matplotlib.pyplot as s
import numpy as np

x = np.array(['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC'])
y = np.array([89,80,69,89,69,79,98,79,89])

s.bar(x,y)
s.show()

# %%
# bargraph-2
import matplotlib.pyplot as s
import numpy as np

x = np.array(['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC'])
y = np.array([89,80,69,89,69,79,98,79,89])

s.barh(x,y)
s.show()

# %%
# bargraph-3
import matplotlib.pyplot as s
import numpy as np

x = np.array(['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC'])
y = np.array([89,80,69,89,69,79,98,79,89])

s.bar(x,y,color = 'red')
s.show()

# %%
# bargraph-4
import matplotlib.pyplot as s
import numpy as np

x = np.array(['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC'])
y = np.array([89,80,69,89,69,79,98,79,89])

s.bar(x,y,color = 'hotpink')
s.show()

# %%
# bargraph-5
import matplotlib.pyplot as s
import numpy as np

x = np.array(['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC'])
y = np.array([89,80,69,89,69,79,98,79,89])

s.bar(x,y,color = '#4CAF50')
s.show()

# %%
# bargraph-6
import matplotlib.pyplot as s
import numpy as np

x = np.array(['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC'])
y = np.array([89,80,69,89,69,79,98,79,89])

s.bar(x,y,width = 0.3)
s.show()

# %%
# bargraph-7
import matplotlib.pyplot as s
import numpy as np

x = np.array(['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC'])
y = np.array([89,80,69,89,69,79,98,79,89])

s.barh(x,y,height = 0.3)
s.show()

# %%
# histogram-1
import matplotlib.pyplot as u
import numpy as np

x = np.random.normal(500,150,500)

u.hist(x)
u.show()

# %%
# histogram-2
import matplotlib.pyplot as u
import numpy as np

x = np.random.normal(900,50,900)

u.hist(x)
u.show()

# %%
# piechart-1
import matplotlib.pyplot as p
import numpy as np

y = np.array([89,80,69,89,69,79,98,79,89])

p.pie(y)
p.show()

# %%
# piechart-2
import matplotlib.pyplot as t
import numpy as np

y = np.array([89,80,69,89,69,79,98,79,89])
mylabels = ['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC']

t.pie(y, labels = mylabels)
t.show()

# %%
# piechart-3
import matplotlib.pyplot as t
import numpy as np

y = np.array([89,80,69,89,69,79,98,79,89])
mylabels = ['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC']

t.pie(y, labels = mylabels, startangle = 90)
t.show()

# %%
# piechart-4
import matplotlib.pyplot as t
import numpy as np

y = np.array([89,80,69,89,69,79,98,79,89])
mylabels = ['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC']
myexplode = [0.3, 0, 0, 0, 0, 0, 0, 0, 0]

t.pie(y, labels = mylabels, explode = myexplode, shadow = True)
t.show()

# %%
# piechart-5
import matplotlib.pyplot as t
import numpy as np

y = np.array([89,80,69,89,69,79,98,79,89])
mylabels = ['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC']
mycolors = ["red", "hotpink", "b", "#4CAF50"]
t.pie(y, labels = mylabels, colors = mycolors)
t.show()

# %%
# piechart-6
import matplotlib.pyplot as t
import numpy as np

y = np.array([89,80,69,89,69,79,98,79,89])
mylabels = ['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC']

t.pie(y, labels = mylabels)
t.legend()
t.show()

# %%
# piechart-7
import matplotlib.pyplot as k
import numpy as np

y = np.array([89,80,69,89,69,79,98,79,89])
mylabels = ['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC']

k.pie(y, labels = mylabels)
k.legend(title = "sem1 subject names:")
k.show()

# %%
# piechart-8
import matplotlib.pyplot as t
import numpy as np

y = np.array([89,80,69,89,69,79,98,79,89])
mylabels = ['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC']
myexplode = [0, 0, 0, 0, 0, 0, 0, 0.3, 0]

t.pie(y, labels = mylabels, explode = myexplode, shadow = True)
t.show()

# %%
# piechart-9
import matplotlib.pyplot as t
import numpy as np

y = np.array([89,80,69,89,69,79,98,79,89])
mylabels = ['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC']
myexplode = [0 , 0, 0.3, 0, 0, 0, 0, 0, 0]
mycolors = ["red", "hotpink", "b", "#4CAF50","black","orange","purple","indigo","violet"]
t.pie(y, labels = mylabels, explode = myexplode, shadow = True, colors = mycolors)
t.show()

# %%
# piechart-10
import matplotlib.pyplot as k
import numpy as np

y = np.array([89,80,69,89,69,79,98,79,89])
mylabels = ['CLAD','IT','C','English','Math-1','Math-2','EVPR','Physics','VDC']
mycolors = ["orange","purple","indigo","violet","red", "hotpink", "b", "#4CAF50","black"]

k.pie(y, labels = mylabels)
k.legend(title = "sem1 subject names:")
k.show()

# %%
# first sum
import matplotlib.pyplot as n

import numpy as np

xhours=np.array([2, 3, 2, 1, 1])

ysubjects=(['python', 'beee', 'maths', 'chem', 'phy'])

n.plot(x, linestyle = 'dotted')

n.show()

# %%
# second sum
import matplotlib.pyplot as p

import numpy as np 

y=np.array([9,5,8,3])

mylabels = [ "Python", "chemistry", "English", "Maths"]

mycolors = [ 'blue', 'orange','green','red']

myexplode =[0.2, 0, 0, 0]

p.pie(y, labels= mylabels,colors= mycolors , explode = myexplode)

p.show()

# %%
# third sum
import matplotlib.pyplot as b
import numpy as np
x=np.array([7,3,6,2,5,1])
y=np.array([56,32,78,67,99,22])
p.plot(x,y,)
p.show()

# %%
# fourth sum
import matplotlib.pyplot as p

import numpy as np

y=np.array([9, 8, 8, 4 ])

mylabels =['CSE','Mech','Civil','ECE']
p.pie(y,labels= mylabels)
p.legend()
p.show
# Out:
# <function matplotlib.pyplot.show>
